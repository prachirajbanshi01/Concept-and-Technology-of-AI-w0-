# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

data = pd.read_csv("/content/drive/MyDrive/Concept&Tech-AI/diabetes.csv")
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
print("\nData Types:")
data.dtypes
# Out:
# Data Types:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
print("Missing Values: ")

missing_info = data.isnull().sum() / len(data) * 100
missing_info
# Out:
# Missing Values:
# Pregnancies                 0.0
# Glucose                     0.0
# BloodPressure               0.0
# SkinThickness               0.0
# Insulin                     0.0
# BMI                         0.0
# DiabetesPedigreeFunction    0.0
# Age                         0.0
# Outcome                     0.0
# dtype: float64

# %%
print("Summary statistics: ")
print(data.describe())
# Out:
# Summary statistics:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# Build Box plots within appropriate columns
import matplotlib.pyplot as plt

for column in data.keys():
    plt.figure(figsize=(8, 4))
    plt.boxplot(data[column], patch_artist=True)
    plt.title(f"Box Plot for {column}")
    plt.ylabel(column)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
data.boxplot(column = "Glucose")

plt.title("Boxplot: By Glucose")
plt.show()

# %%
# Build Histograms appropriate columns: 'Pregancies'
import matplotlib.pyplot as plt

column = data['Pregnancies']
plt.figure(figsize=(8, 4))
plt.hist(column, bins = 8, edgecolor='black', alpha = 0.7)
plt.title("Histogram for 'Pregnancies'")
plt.xlabel('Pregnancies')  # Label the x-axis with the column name
plt.ylabel("Frequency")
plt.grid(linestyle='--', alpha=0.7)
plt.show()

# %%
# Build Histograms appropriate columns: 'Glucose'

import matplotlib.pyplot as plt

column = data['Glucose']
plt.figure(figsize=(8, 4))
plt.hist(column, bins = 8, edgecolor='black', alpha = 0.7)
plt.title("Histogram for 'Glucose'")
plt.xlabel('Glucose')  # Label the x-axis with the column name
plt.ylabel("Frequency")
plt.grid(linestyle='--', alpha=0.7)
plt.show()

# %%
# Build Histograms appropriate columns: 'BloodPressure'

import matplotlib.pyplot as plt

column = data['BloodPressure']
plt.figure(figsize=(8, 4))
plt.hist(column, bins = 8, edgecolor='black', alpha = 0.7)
plt.title("Histogram for 'BloodPressure'")
plt.xlabel('BloodPressure')  # Label the x-axis with the column name
plt.ylabel("Frequency")
plt.grid(linestyle='--', alpha=0.7)
plt.show()

# %%
# Build Histograms appropriate columns: 'SkinThickness'

import matplotlib.pyplot as plt

column = data['SkinThickness']
plt.figure(figsize=(8, 4))
plt.hist(column, bins = 8, edgecolor='black', alpha = 0.7)
plt.title("Histogram for 'SkinThickness'")
plt.xlabel('SkinThickness')  # Label the x-axis with the column name
plt.ylabel("Frequency")
plt.grid(linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns
import numpy as np

# Create a DataFrame for the numerical columns
numerical_columns = ["Pregnancies", "Glucose", "BloodPressure"]

# Calculate the correlation matrix
correlation_matrix = data[numerical_columns].corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
# Feature Selection: X

# Identify feature columns (excluding non-numeric columns)
X = data[["Pregnancies", "Glucose", "BloodPressure", "SkinThickness",
                     "Insulin", "BMI", "DiabetesPedigreeFunction", "Age"]]

# Print feature columns X
print("\nFeature columns X(numeric columns):")
X
# Out:
# Feature columns X(numeric columns):
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
# Feature Selection: y

# Identify target columns

y = data["Outcome"]
# Print target column y
print("\nTarget column y:")
y
# Out:
# Target column y:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
import pandas as pd
import numpy as np

def train_test_split_scratch(X, y, test_size=0.3, random_seed=42):
    """
    Splits dataset into train and test sets.

    Arguments:
    X : np.ndarray
        Feature matrix.
    y : np.ndarray
        Target array.
    test_size : float
        Proportion of the dataset to include in the test split (0 < test_size < 1).
    random_seed : int
        Seed for reproducibility.

    Returns:
    X_train, X_test, y_train, y_test : np.ndarray
        Training and testing splits of features and target.
    """
    np.random.seed(random_seed)
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)  # Shuffle the indices

    test_split_size = int(len(X) * test_size)
    test_indices = indices[:test_split_size]
    train_indices = indices[test_split_size:]

    # Create the training and testing splits for features and target
    X_train = X[train_indices]
    X_test = X[test_indices]
    y_train = y[train_indices]
    y_test = y[test_indices]

    return X_train, X_test, y_train, y_test

# Extract feature columns (X) and target column (y)
# # Assuming 'target' is the column we want to predict and the rest are features
# X = data.drop(columns=['Outcome']).values
# y = data['Outcome'].values  # Extract the target column

X = data[["Pregnancies", "Glucose", "BloodPressure", "SkinThickness",
                     "Insulin", "BMI", "DiabetesPedigreeFunction", "Age"]].values
y = data['Outcome']
# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split_scratch(X, y, test_size=0.3)

# Print shapes of the resulting splits
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (538, 8)
# Shape of X_test: (230, 8)
# Shape of y_train: (538,)
# Shape of y_test: (230,)

# %%
def euclidean_distance(point1, point2):
    """
    Calculate the Euclidean distance between two points in n-dimensional space.

    Arguments:
    point1 : np.ndarray
        The first point as a numpy array.
    point2 : np.ndarray
        The second point as a numpy array.

    Returns:
    float
        The Euclidean distance between the two points.

    Raises:
    ValueError: If the input points do not have the same dimensionality.
    """

    if point1.shape != point2.shape:
        raise ValueError("Points must have the same dimensions to calculate Euclidean distance.")


    #distance = complete code
    # distance = np.linalg.norm(point1[['X', 'Y']].values - point2[['X', 'Y']].values, axis=1)
    # return distance
    distance = np.sqrt(np.sum((point1 - point2) ** 2))
    return distance

# Example points
point1 = np.array([1, 2, 3])
point2 = np.array([2, 4, 6])

# Calculate Euclidean distance
distance = euclidean_distance(point1, point2)

print(f"The Euclidean distance between the points is: {distance}")
# Out:
# The Euclidean distance between the points is: 3.7416573867739413

# %%
def euclidean_distance(point1, point2):
    """
    Calculate the Euclidean distance between two points in n-dimensional space.

    Arguments:
    point1 : np.ndarray
        The first point as a numpy array.
    point2 : np.ndarray
        The second point as a numpy array.

    Returns:
    float
        The Euclidean distance between the two points.

    Raises:
    ValueError: If the input points do not have the same dimensionality.
    """

    if point1.shape != point2.shape:
        raise ValueError("Points must have the same dimensions to calculate Euclidean distance.")


    #distance = complete code
    # distance = np.linalg.norm(point1[['X', 'Y']].values - point2[['X', 'Y']].values, axis=1)
    # return distance
    distance = np.sqrt(np.sum((point1 - point2) ** 2))
    return distance

try:

    point1 = np.array([3, 4])
    point2 = np.array([0, 0])


    result = euclidean_distance(point1, point2)


    expected_result = 5.0
    assert np.isclose(result, expected_result), f"Expected {expected_result}, but got {result}"

    print("Test passed successfully!")
except ValueError as ve:
    print(f"ValueError: {ve}")
except AssertionError as ae:
    print(f"AssertionError: {ae}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Test passed successfully!

# %%
def knn_predict_single(query, X_train, y_train, k=3):
    """
    Predict the class label for a single query using the K-nearest neighbors algorithm.

    Arguments:
    query : np.ndarray
        The query point for which the prediction is to be made.
    X_train : np.ndarray
        The training feature matrix.
    y_train : np.ndarray
        The training labels.
    k : int, optional
        The number of nearest neighbors to consider (default is 3).

    Returns:
    int
        The predicted class label for the query.
    """

    distances = [euclidean_distance(query, x) for x in X_train]

    sorted_indices = np.argsort(distances)

    nearest_indices = sorted_indices[:k]

    nearest_labels = y_train[nearest_indices]

    prediction = np.bincount(nearest_labels).argmax()

    return prediction

# Example
X_train = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])
y_train = np.array([0, 1, 0, 1])

# Query point
query = np.array([4, 5])

# Predict class label for the query point
k = 3
predicted_label = knn_predict_single(query, X_train, y_train, k)

print(f"Predicted class label for query {query}: {predicted_label}")
# Out:
# Predicted class label for query [4 5]: 0

# %%
def knn_predict(X_test, X_train, y_train, k=3):
    """
    Predict the class labels for all test samples using the K-nearest neighbors algorithm.

    Arguments:
    X_test : np.ndarray
        The test feature matrix.
    X_train : np.ndarray
        The training feature matrix.
    y_train : np.ndarray
        The training labels.
    k : int, optional
        The number of nearest neighbors to consider (default is 3).

    Returns:
    np.ndarray
        An array of predicted class labels for the test samples.
    """

    predictions = [knn_predict_single(x, X_train, y_train, k) for x in X_test]
    return np.array(predictions)

# Example

X_train = np.array([[2, 3], [6, 7], [10, 11], [14, 15]])
y_train = np.array([0, 1, 0, 1])

X_test = np.array([[2,3], [6,7]])

predicted_labels = knn_predict(X_test, X_train, y_train, k)

print("Predicted class labels for X_test: {predicted_labels}")
# Out:
# Predicted class labels: [0 1 0 1]

# %%
def knn_predict(X_test, X_train, y_train, k=3):
    """
    Predict the class labels for all test samples using the K-nearest neighbors algorithm.

    Arguments:
    X_test : np.ndarray
        The test feature matrix.
    X_train : np.ndarray
        The training feature matrix.
    y_train : np.ndarray
        The training labels.
    k : int, optional
        The number of nearest neighbors to consider (default is 3).

    Returns:
    np.ndarray
        An array of predicted class labels for the test samples.
    """

    predictions = [knn_predict_single(x, X_train, y_train, k) for x in X_test]
    return np.array(predictions)

# Example data
X_train = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])
y_train = np.array([0, 1, 0, 1])
X_test = np.array([[2, 3], [6, 7], [8, 9], [1, 1], [4, 4], [7, 7]])
y_test = np.array([0, 0, 1, 0, 1, 1])


# Try block
try:
    X_test_sample = X_test[:5]
    y_test_sample = y_test[:5]

    predictions = knn_predict(X_test_sample, X_train, y_train, k=3)

    print("Predictions:", predictions)
    print("Actual labels:", y_test_sample)

    assert predictions.shape == y_test_sample.shape, (
        "The shape of predictions does not match the shape of the actual labels."
    )

    print("Test case passed successfully!")
except AssertionError as ae:
    print(f"AssertionError: {ae}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Predictions: [0 1 1 0 0]
# Actual labels: [0 0 1 0 1]
# Test case passed successfully!

# %%
def compute_accuracy(y_true, y_pred):
    """
    Compute the accuracy of predictions.

    Arguments:
    y_true : np.ndarray
        The true labels.
    y_pred : np.ndarray
        The predicted labels.

    Returns:
    float
        The accuracy as a percentage (0 to 100).
    """
    correct_predictions = np.sum(y_true == y_pred)
    total_predictions = len(y_true)
    accuracy = (correct_predictions / total_predictions) * 100
    return accuracy


try:
    predictions = knn_predict(X_test, X_train, y_train, k=3)

    accuracy = compute_accuracy(y_test, predictions)

    print(f"Accuracy of the KNN model on the test set: {accuracy:.2f}%")
except Exception as e:
    print(f"An unexpected error occurred during prediction or accuracy computation: {e}")
# Out:
# Accuracy of the KNN model on the test set: 50.00%

# %%
import matplotlib.pyplot as plt

def experiment_knn_k_values(X_train, y_train, X_test, y_test, k_values):
    """
    Run KNN predictions for different values of k and plot the accuracies.

    Arguments:
    X_train : np.ndarray
        The training feature matrix.
    y_train : np.ndarray
        The training labels.
    X_test : np.ndarray
        The test feature matrix.
    y_test : np.ndarray
        The test labels.
    k_values : list of int
        A list of k values to experiment with.

    Returns:
    dict
        A dictionary with k values as keys and their corresponding accuracies as values.
    """
    accuracies = {}

    for k in k_values:
      predictions = knn_predict(X_test, X_train, y_train, k=3)
      accuracy = compute_accuracy(y_test, predictions)
      accuracies[k] = accuracy

      print(f"Accuracy for k={k}: {accuracy:.2f}%")


    plt.figure(figsize=(10, 5))
    plt.plot(k_values, list(accuracies.values()), marker='o')
    plt.xlabel('k (Number of Neighbors)')
    plt.ylabel('Accuracy (%)')
    plt.title('Accuracy of KNN with Different Values of k')
    plt.grid(True)
    plt.show()

    return accuracies


k_values = range(1, 10)

try:
    accuracies = experiment_knn_k_values(X_train, y_train, X_test, y_test, k_values)
    print("Experiment completed. Check the plot for the accuracy trend.")
except Exception as e:
    print(f"An unexpected error occurred during the experiment: {e}")
# Out:
# Accuracy for k=1: 50.00%
# Accuracy for k=2: 50.00%
# Accuracy for k=3: 50.00%
# Accuracy for k=4: 50.00%
# Accuracy for k=5: 50.00%
# Accuracy for k=6: 50.00%
# Accuracy for k=7: 50.00%
# Accuracy for k=8: 50.00%
# Accuracy for k=9: 50.00%
# Experiment completed. Check the plot for the accuracy trend.
